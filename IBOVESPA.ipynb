# %% [markdown]
# <a href="https://colab.research.google.com/github/joni901/Benford_Law/blob/main/IBOVESPA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

with open(r'/content/AcoesIndices_2023-12-27.csv', "r",encoding='latin1') as file:
    r_file = file.readlines()
    texto_completo = ''.join(r_file)
    linhas = texto_completo.split('\n')[2:]
    lista_de_listas = [linha.split(';') if ';' in linha else [linha] for linha in linhas]

# %%
colunas = {'Empresa': [], 'Código': [], 'Índices dos quais participa': []}

# Preencher o dicionário com os dados
for linha in lista_de_listas:
  nova_linha = []
  for l, valor in enumerate(linha):

    if l == 0:
      colunas['Empresa'].append(valor)
    elif l == 1:
      colunas['Código'].append(valor)
    elif l>3:
      nova_linha.append(valor if l <1 else ' '.join(map(str, linha[3:])))
      colunas['Índices dos quais participa'].append(nova_linha)
del colunas['Código'][0]
del colunas['Empresa'][0]
del colunas["Empresa"][512]

for n in range(len(colunas["Índices dos quais participa"])):
  colunas["Índices dos quais participa"][n]=str(colunas["Índices dos quais participa"][n][0])

# %%
df = pd.DataFrame(colunas)
df.head()
# Out:
#         Empresa   Código                        Índices dos quais participa
# 0            3M      DRN                                              BDRX
# 1  3R PETROLEUM  ON   NM  GPTW,IBOV,IBRA,IBXL,IBXX,IGCT,IGCX,IGNM,ITAG,I...
# 2       3TENTOS  ON   NM           AGFS,IBRA,ICON,IGCT,IGCX,IGNM,ITAG,SMLL
# 3        ABBVIE      DRN                                              BDRX
# 4    ABC BRASIL  PN   N2                IBRA,IDIV,IFNC,IGCT,IGCX,ITAG,SMLL

# %%
indices=['IGCX', "ITAG", 'IGCT', 'IGNM']

empresas=[]

for indice in indices:
  for n in range(len(df['Índices dos quais participa'])):
    if indice in df['Índices dos quais participa'][n]:
      if df["Empresa"][n] not in empresas:
        empresas.append(df["Empresa"][n])
print(empresas)
# Out:
# ['3R PETROLEUM', '3TENTOS', 'ABC BRASIL', 'AERIS', 'AES BRASIL', 'AGROGALAXY', 'ALLIAR', 'ALLIED', 'ALLOS', 'ALPARGATAS', 'ALPER S.A.', 'ALPHAVILLE', 'ALUPAR', 'AMBIPAR', 'ANIMA', 'AREZZO CO', 'ARMAC', 'ASSAI', 'AUREN', 'AZUL', 'B3', 'BANCO BMG', 'BANCO PAN', 'BANRISUL', 'BBSEGURIDADE', 'BEMOBI TECH', 'BLAU', 'BOA SAFRA', 'BR PARTNERS', 'BRADESCO', 'BRADESPAR', 'BRASIL', 'BRASILAGRO', 'BRASKEM', 'BRF SA', 'BRISANET', 'BTGP BANCO', 'CAIXA SEGURI', 'CAMIL', 'CARREFOUR BR', 'CASAS BAHIA', 'CBA', 'CCR SA', 'CEA MODAS', 'CEDRO', 'CELESC', 'CEMIG', 'CIELO', 'CLEARSALE', 'COGNA ON', 'COPASA', 'COPEL', 'COSAN', 'CPFL ENERGIA', 'CRUZEIRO EDU', 'CSNMINERACAO', 'CSU DIGITAL', 'CURY S/A', 'CVC BRASIL', 'CYRELA REALT', 'D1000VFARMA', 'DASA', 'DESKTOP', 'DEXCO', 'DEXXOS PAR', 'DIMED', 'DIRECIONAL', 'DOTZ SA', 'ECORODOVIAS', 'ELETROBRAS', 'ELETROMIDIA', 'EMBRAER', 'ENAUTA PART', 'ENERGISA', 'ENEVA', 'ENGIE BRASIL', 'ENJOEI', 'EQUATORIAL', 'ESPACOLASER', 'ESTAPAR', 'EUCATEX', 'EVEN', 'EZTEC', 'FER HERINGER', 'FERBASA', 'FLEURY', 'FRAS-LE', 'GAFISA', 'GERDAU', 'GERDAU MET', 'GETNINJAS', 'GOL', 'GPS', 'GRENDENE', 'GRUPO MATEUS', 'GRUPO NATURA', 'GRUPO SBF', 'GRUPO SOMA', 'GUARARAPES', 'HAPVIDA', 'HBR REALTY', 'HELBOR', 'HIDROVIAS', 'HYPERA', 'IGUATEMI S.A', 'IMC S/A', 'INFRACOMM', 'INTELBRAS', 'IOCHP-MAXION', 'IRANI', 'IRBBRASIL RE', 'ITAUSA', 'ITAUUNIBANCO', 'JALLESMACHAD', 'JBS', 'JHSF PART', 'JSL', 'KEPLER WEBER', 'KLABIN S/A', 'KORA SAUDE', 'LAVVI', 'LOCALIZA', 'LOCAWEB', 'LOG COM PROP', 'LOG-IN', 'LOJAS RENNER', 'LOPES BRASIL', 'LUPATECH', 'M.DIASBRANCO', 'MAGAZ LUIZA', 'MARCOPOLO', 'MARFRIG', 'MATER DEI', 'MELIUZ', 'MELNICK', 'MERCANTIL', 'METAL LEVE', 'MILLS', 'MINERVA', 'MITRE REALTY', 'MOBLY', 'MOURA DUBEUX', 'MOVIDA', 'MRV', 'MULTILASER', 'MULTIPLAN', 'NEOENERGIA', 'NEOGRID', 'OCEANPACT', 'ODONTOPREV', 'ONCOCLINICAS', 'ORIZON', 'OSX BRASIL', 'OUROFINO S/A', 'P.ACUCAR-CBD', 'PADTEC', 'PAGUE MENOS', 'PDG REALT', 'PETROBRAS', 'PETRORECSA', 'PETRORIO', 'PETZ', 'PINE', 'PLANOEPLANO', 'PORTO SEGURO', 'PORTOBELLO', 'POSITIVO TEC', 'PRINER', 'PROFARMA', 'QUALICORP', 'QUERO-QUERO', 'RAIADROGASIL', 'RAIZEN', 'RANDON PART', 'REDE D OR', 'RNI', 'ROMI', 'RUMO S.A.', 'SABESP', 'SANEPAR', 'SANTOS BRP', 'SAO CARLOS', 'SAO MARTINHO', 'SEQUOIA LOG', 'SER EDUCA', 'SERENA', 'SIMPAR', 'SLC AGRICOLA', 'SMART FIT', 'SPRINGS', 'SUZANO S.A.', 'SYN PROP TEC', 'TAESA', 'TAURUS ARMAS', 'TC', 'TECHNOS', 'TECNISA', 'TEGMA', 'TENDA', 'TERRASANTAPA', 'TIM', 'TIME FOR FUN', 'TOTVS', 'TRACK FIELD', 'TRAN PAULIST', 'TRISUL', 'TRIUNFO PART', 'TUPY', 'ULTRAPAR', 'UNICASA', 'UNIFIQUE', 'USIMINAS', 'VALE', 'VALID', 'VAMOS', 'VESTE', 'VIBRA', 'VITTIA', 'VIVARA S.A.', 'VIVEO', 'VIVER', 'VULCABRAS', 'WDC NETWORKS', 'WEG', 'WESTWING', 'WILSON SONS', 'WIZ CO', 'YDUQS PART', 'ZAMP S.A.', 'BAHEMA', 'BANESE', 'BIOMM', 'COTEMINAS', 'GER PARANAP', 'GRAZZIOTIN', 'INEPAR', 'PETTENATI', 'SANTANDER BR']
